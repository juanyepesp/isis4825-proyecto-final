# %% [markdown]
# # Preprocesamiento de las imágenes
#
# Este notebook es para correr los scripts de transformación de imágenes para poder alimentar los modelos. Tienen que poner el path completo para que lo pueda leer. Dejo los míos de ejemplo.

# %%
# !python filter.py /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/test /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/test
# Out:
# Processed: IN /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/test/video_13min_340.jpg -> OUT /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/test/video_13min_340.jpg
# Processed: IN /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/test/video_13min_426.jpg -> OUT /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/test/video_13min_426.jpg
# Processed: IN /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/test/video_13min_432.jpg -> OUT /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/test/video_13min_432.jpg
# Processed: IN /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/test/video_11min_518.jpg -> OUT /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/test/video_11min_518.jpg
# ...

# %%
# !python filter.py /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/train /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/train
# Out:
# Processed: IN /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/train/video_11min_295.jpg -> OUT /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/train/video_11min_295.jpg
# Processed: IN /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/train/video_11min_281.jpg -> OUT /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/train/video_11min_281.jpg
# Processed: IN /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/train/video_11min_518.jpg -> OUT /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/train/video_11min_518.jpg
# Processed: IN /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/train/video_11min_256.jpg -> OUT /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/train/video_11min_256.jpg
# ...

# %%
# !python filter.py /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/val /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/val
# Out:
# Processed: IN /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/val/video_13min_368.jpg -> OUT /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/val/video_13min_368.jpg
# Processed: IN /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/val/video_13min_354.jpg -> OUT /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/val/video_13min_354.jpg
# Processed: IN /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/val/video_13min_383.jpg -> OUT /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/val/video_13min_383.jpg
# Processed: IN /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Imagenes/val/video_13min_397.jpg -> OUT /Users/juan/Local/2025-10loc/ISIS4825/proyecto/repositorio/data/Procesado/val/video_13min_397.jpg
# ...
